# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IMB Watson Studio

# %% [markdown]
# __Luis Rodriguez__ <br>
# Social Media Marketing Manager

# %% [markdown]
# *I am interested in data sciene because I want to further my knowledge of how Python can be used. Data science is also used for machine learning which is another field that I'm very interested in.*

# %% [markdown]
# The code in cell 5 is supposed to compute a very simple arithmetic problem.

# %%
1 + 1

# %% [markdown]
# - First
# - Second
# - Third
# 1. One
# 1. Two
# 1. Three
# <br>
# [https://www.coursera.org/specializations/data-science-fundamentals-python-sql]
